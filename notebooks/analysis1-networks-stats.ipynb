# %% [markdown]
# ## Analysis of semantic networks generated from word2vec, GloVe and USF Norms datasets

# %%
import pandas as pd
import networkx as nx
import numpy as np
import os
import locale
import glob

from matplotlib.pyplot import *

pd.set_option('display.float_format', 
              lambda x: locale.format('%.0f', x, grouping=True) if abs(x)>1000 else locale.format('%.2f', x))

# %%
results_all = pd.concat([
    pd.read_csv('../semnet_compare/results/undirected_results.csv', index_col=0),
    pd.read_csv('../semnet_compare/results/directed_results.csv', index_col=0)],
    axis=1).T

# %%
to_rename = {
    'aspl': 'L',  # Average shortest path length
    'avg_degree': '<k>', # Average node degree
    'cc' : 'C', # clustering coefficient
    'connectedness': 'C_k', # connectedness (% of nodes in the largest connected component)
    'diameter': 'D', 
    'n_edges': 'm',
    'n_nodes': 'n',
    'rnd_aspl': 'L_{rnd}',
    'rnd_cc':'C_{rnd}',
}
results_all = results_all.rename(columns=to_rename)

# convert to integers relevant fields
locale.setlocale(locale.LC_ALL, '')

results_all['D'] = results_all['D'].map(lambda x: np.int(x))
    
to_prec3 = ['C', 'C_{rnd}']
for col in to_prec3:
    results_all[col] = results_all[col].map(lambda x: "%.3f"%x)

results_all['<k>'] = results_all['<k>'].map(lambda x: "%.1f"%x)

results_all.columns=['$' + col +'$'for col in results_all.columns]
results_all
# Out:
#                   $L$ $<k>$    $C$  $C_k$  $D$    $m$   $n$  $L_{rnd}$  \
# USF undirected   3.04  22.0  0.186 100.00    5 55,236 5,018       3.03
# word2vec-cos     4.24  21.3  0.325  99.84   12 52,317 4,902       3.05
# word2vec-dot     4.19  22.1  0.356  96.35   13 44,442 4,022       2.92
# glove-cos        4.61  22.1  0.373  98.88   12 51,244 4,632       2.98
# glove-dot        4.28  22.0  0.395  98.16   15 46,534 4,229       2.96
# USF directed     4.26  12.7  0.187  96.51   10 63,619 5,018       3.62
# word2vec-cs-cos  4.79  12.6  0.238  99.32   11 62,764 4,977       3.64
# word2vec-cs-dot  4.93  12.6  0.248  93.55   16 62,775 4,977       3.59
# word2vec-knn-cos 4.77  12.7  0.232  99.32   12 63,165 4,977       3.63
# word2vec-knn-dot 5.11  12.7  0.234  96.08   15 63,165 4,977       3.62
# glove-cs-cos     5.05  12.4  0.266  97.07   13 61,619 4,988       3.64
# glove-cs-dot     5.22  12.0  0.275  94.17   15 59,766 4,988       3.67
# glove-knn-cos    5.03  12.7  0.259  97.91   13 63,262 4,988       3.62
# glove-knn-dot    5.13  12.7  0.272  94.55   15 63,262 4,988       3.61
#
#                  $C_{rnd}$  $s$
# USF undirected       0.004 0.44
# word2vec-cos         0.004 0.44
# word2vec-dot         0.006 0.55
# glove-cos            0.005 0.48
# glove-dot            0.005 0.52
# USF directed         0.005 0.25
# word2vec-cs-cos      0.005 0.25
# word2vec-cs-dot      0.006 0.25
# word2vec-knn-cos     0.005 0.26
# word2vec-knn-dot     0.005 0.26
# glove-cs-cos         0.005 0.25
# glove-cs-dot         0.005 0.24
# glove-knn-cos        0.005 0.25
# glove-knn-dot        0.005 0.25

# %%
results = results_all.loc[filter(lambda x: 'USF' in x or 'cos' in x, results_all.index)]
results.index = pd.Index(map(lambda x: x if 'USF' in x else x[:x.find('-cos')], results.index))
results
# Out:
#                 $L$ $<k>$    $C$  $C_k$  $D$    $m$   $n$  $L_{rnd}$  \
# USF undirected 3.04  22.0  0.186 100.00    5 55,236 5,018       3.03
# word2vec       4.24  21.3  0.325  99.84   12 52,317 4,902       3.05
# glove          4.61  22.1  0.373  98.88   12 51,244 4,632       2.98
# USF directed   4.26  12.7  0.187  96.51   10 63,619 5,018       3.62
# word2vec-cs    4.79  12.6  0.238  99.32   11 62,764 4,977       3.64
# word2vec-knn   4.77  12.7  0.232  99.32   12 63,165 4,977       3.63
# glove-cs       5.05  12.4  0.266  97.07   13 61,619 4,988       3.64
# glove-knn      5.03  12.7  0.259  97.91   13 63,262 4,988       3.62
#
#                $C_{rnd}$  $s$
# USF undirected     0.004 0.44
# word2vec           0.004 0.44
# glove              0.005 0.48
# USF directed       0.005 0.25
# word2vec-cs        0.005 0.25
# word2vec-knn       0.005 0.26
# glove-cs           0.005 0.25
# glove-knn          0.005 0.25
